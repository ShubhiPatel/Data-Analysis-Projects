# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("hr-data.xlsx")

# %%
df
# Out:
#                     Name  Emp ID  Gender Education Qualification Date of Join  \
# 0           Barr Faughny  AC0001    Male       Bachelor's Degree   2020-06-12
# 1    Dennison Crosswaite  AC0002  Female                 Diploma   2021-02-18
# 2        Gunar Cockshoot  AC0003    Male     High School Diploma   2022-09-05
# 3         Wilone O'Kielt  AC0004  Female       Bachelor's Degree   2019-11-20
# 4           Gigi Bohling  AC0005    Male         Master's Degree   2018-04-08
# ..                   ...     ...     ...                     ...          ...
# 156      Michael Walkson  AC0157    Male         Master's Degree   2017-11-26
# 157        Anaya Agarwal  AC0158  Female     High School Diploma   2023-04-09
# 158          Krish Rawat  AC0159    Male                 Diploma   2020-06-02
# 159          Siya Sharma  AC0160  Female       Bachelor's Degree   2019-08-26
# 160        Kabir Trivedi  AC0161    Male     High School Diploma   2022-03-19
#
# ...

# %%
df.head()
# Out:
#                   Name  Emp ID  Gender Education Qualification Date of Join  \
# 0         Barr Faughny  AC0001    Male       Bachelor's Degree   2020-06-12
# 1  Dennison Crosswaite  AC0002  Female                 Diploma   2021-02-18
# 2      Gunar Cockshoot  AC0003    Male     High School Diploma   2022-09-05
# 3       Wilone O'Kielt  AC0004  Female       Bachelor's Degree   2019-11-20
# 4         Gigi Bohling  AC0005    Male         Master's Degree   2018-04-08
#
#               Job Title  Salary   Age  Leave Balance
# 0           Chocolatier   51300  26.0             13
# 1   Production Operator   38300  32.7             12
# 2   Packaging Associate   31400  34.3             16
# 3  Marketing Specialist   60700  29.6             21
# 4    Research Scientist   77300  30.3             23

# %%
df.tail()
# Out:
#                 Name  Emp ID  Gender Education Qualification Date of Join  \
# 156  Michael Walkson  AC0157    Male         Master's Degree   2017-11-26
# 157    Anaya Agarwal  AC0158  Female     High School Diploma   2023-04-09
# 158      Krish Rawat  AC0159    Male                 Diploma   2020-06-02
# 159      Siya Sharma  AC0160  Female       Bachelor's Degree   2019-08-26
# 160    Kabir Trivedi  AC0161    Male     High School Diploma   2022-03-19
#
#                 Job Title  Salary   Age  Leave Balance
# 156       Product Manager   82300  34.4             18
# 157           Chocolatier   52900  30.5              8
# 158     Marketing Manager   71100  31.6             13
# 159    Research Scientist   76900  33.2             17
# 160  Sales Representative   46400  37.1             11

# %%
df.shape
# Out:
# (161, 9)

# %%
df.isnull()
# Out:
#       Name  Emp ID  Gender  Education Qualification  Date of Join  Job Title  \
# 0    False   False   False                    False         False      False
# 1    False   False   False                    False         False      False
# 2    False   False   False                    False         False      False
# 3    False   False   False                    False         False      False
# 4    False   False   False                    False         False      False
# ..     ...     ...     ...                      ...           ...        ...
# 156  False   False   False                    False         False      False
# 157  False   False   False                    False         False      False
# 158  False   False   False                    False         False      False
# 159  False   False   False                    False         False      False
# 160  False   False   False                    False         False      False
#
#      Salary    Age  Leave Balance
# ...

# %%
df.isnull().sum()
# Out:
# Name                       0
# Emp ID                     0
# Gender                     0
# Education Qualification    0
# Date of Join               0
# Job Title                  0
# Salary                     0
# Age                        0
# Leave Balance              0
# dtype: int64

# %%
df["Job Title"].value_counts()
# Out:
# Job Title
# Packaging Associate     22
# Production Operator     20
# Sales Representative    18
# Chocolatier             17
# Quality Control         17
# Research Analyst        16
# Product Manager         16
# Research Scientist      15
# Marketing Specialist    10
# Marketing Manager       10
# Name: count, dtype: int64

# %%
df["Job Title"].value_counts().index
# Out:
# Index(['Packaging Associate', 'Production Operator', 'Sales Representative',
#        'Chocolatier', 'Quality Control', 'Research Analyst', 'Product Manager',
#        'Research Scientist', 'Marketing Specialist', 'Marketing Manager'],
#       dtype='object', name='Job Title')

# %%
x =df["Job Title"].value_counts().index

# %%
df["Job Title"].value_counts().values
# Out:
# array([22, 20, 18, 17, 17, 16, 16, 15, 10, 10], dtype=int64)

# %%
y = df["Job Title"].value_counts().values

# %%
plt.figure(figsize = (6,5))
plt.pie(y , labels = x, autopct= "%0.2f%%")
plt.title("People in each Job")
plt.show()

# %%
plt.barh(x,y)
plt.title("Count of people in each Job")
plt.show()

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    88
# Male      73
# Name: count, dtype: int64

# %%
df["Gender"].value_counts().index
# Out:
# Index(['Female', 'Male'], dtype='object', name='Gender')

# %%
x =df["Gender"].value_counts().index

# %%
df["Gender"].value_counts().values
# Out:
# array([88, 73], dtype=int64)

# %%
y=df["Gender"].value_counts().values

# %%
plt.figure(figsize=(3,4))
sns.countplot( x=df["Gender"])
plt.title("Gender breakdown of the staff")
plt.show()

# %%
df["Age"].value_counts()
# Out:
# Age
# 31.6    5
# 31.1    5
# 32.7    4
# 33.8    4
# 30.3    4
#        ..
# 37.7    1
# 50.3    1
# 60.8    1
# 26.1    1
# 37.1    1
# Name: count, Length: 102, dtype: int64

# %%
df["Age"].value_counts().shape
# Out:
# (102,)

# %%
sns.histplot(x = df["Age"], bins = 10,)
plt.title("Age spread of the staff")
plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df["Job Title"].value_counts()
# Out:
# Job Title
# Packaging Associate     22
# Production Operator     20
# Sales Representative    18
# Chocolatier             17
# Quality Control         17
# Research Analyst        16
# Product Manager         16
# Research Scientist      15
# Marketing Specialist    10
# Marketing Manager       10
# Name: count, dtype: int64

# %%
df["Job Title"].value_counts().index
# Out:
# Index(['Packaging Associate', 'Production Operator', 'Sales Representative',
#        'Chocolatier', 'Quality Control', 'Research Analyst', 'Product Manager',
#        'Research Scientist', 'Marketing Specialist', 'Marketing Manager'],
#       dtype='object', name='Job Title')

# %%
df["Salary"].value_counts()
# Out:
# Salary
# 51300    3
# 52700    3
# 36000    3
# 43000    3
# 51100    3
#         ..
# 29700    1
# 44800    1
# 49000    1
# 79300    1
# 46400    1
# Name: count, Length: 135, dtype: int64

# %%
df["Salary"].value_counts().shape
# Out:
# (135,)

# %%
df.groupby("Job Title").count()
# Out:
#                       Name  Emp ID  Gender  Education Qualification  \
# Job Title
# Chocolatier             17      17      17                       17
# Marketing Manager       10      10      10                       10
# Marketing Specialist    10      10      10                       10
# Packaging Associate     22      22      22                       22
# Product Manager         16      16      16                       16
# Production Operator     20      20      20                       20
# Quality Control         17      17      17                       17
# Research Analyst        16      16      16                       16
# Research Scientist      15      15      15                       15
# Sales Representative    18      18      18                       18
#
#                       Date of Join  Salary  Age  Leave Balance
# Job Title
# Chocolatier                     17      17   17             17
# Marketing Manager               10      10   10             10
# ...

# %%
by_title = df.groupby("Job Title")

# %%
by_title.max("Salary").sort_values(by="Salary", ascending = False)
# Out:
#                       Salary   Age  Leave Balance
# Job Title
# Product Manager        85000  65.1             23
# Research Scientist     79300  65.4             23
# Marketing Manager      74900  62.6             27
# Marketing Specialist   63600  44.1             23
# Research Analyst       60000  61.1             23
# Chocolatier            54900  55.9             25
# Sales Representative   49800  53.5             23
# Quality Control        45000  66.2             24
# Production Operator    39800  46.2             24
# Packaging Associate    36200  66.7             37

# %%
by_title.max("Salary").sort_values(by="Salary", ascending = False).index
# Out:
# Index(['Product Manager', 'Research Scientist', 'Marketing Manager',
#        'Marketing Specialist', 'Research Analyst', 'Chocolatier',
#        'Sales Representative', 'Quality Control', 'Production Operator',
#        'Packaging Associate'],
#       dtype='object', name='Job Title')

# %%
df.groupby('Job Title')['Salary'].mean().reset_index()
# Out:
#               Job Title        Salary
# 0           Chocolatier  52176.470588
# 1     Marketing Manager  73530.000000
# 2  Marketing Specialist  62170.000000
# 3   Packaging Associate  33409.090909
# 4       Product Manager  82825.000000
# 5   Production Operator  37500.000000
# 6       Quality Control  43135.294118
# 7      Research Analyst  57812.500000
# 8    Research Scientist  77566.666667
# 9  Sales Representative  47511.111111

# %%
avg_salary = df.groupby('Job Title')['Salary'].mean().reset_index()

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='Job Title', y='Salary', data= avg_salary, palette='viridis')
plt.xlabel('Job Title')
plt.ylabel('Average Salary ($)')
plt.title('Average Salary by Job Title')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout() 
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Education Qualification', y='Salary', data=df)
plt.xlabel('Education Qualification')
plt.ylabel('Salary')
plt.title('Salary Distribution by Education Qualification')
plt.show()

# %%
avg_salary = df.groupby('Education Qualification')['Salary'].mean().reset_index()


plt.figure(figsize=(7, 5))
sns.barplot(x='Education Qualification', y='Salary', data=avg_salary, palette='viridis')
plt.xlabel('Education Qualification')
plt.ylabel('Average Salary')
plt.title('Average Salary by Education Qualification')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     161 non-null    object
#  1   Emp ID                   161 non-null    object
#  2   Gender                   161 non-null    object
#  3   Education Qualification  161 non-null    object
#  4   Date of Join             161 non-null    datetime64[ns]
#  5   Job Title                161 non-null    object
#  6   Salary                   161 non-null    int64
#  7   Age                      161 non-null    float64
#  8   Leave Balance            161 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 11.4+ KB

# %%
df["Date of Join"].dt.year
# Out:
# 0      2020
# 1      2021
# 2      2022
# 3      2019
# 4      2018
#        ...
# 156    2017
# 157    2023
# 158    2020
# 159    2019
# 160    2022
# Name: Date of Join, Length: 161, dtype: int32

# %%
df["Joining Year"]= df["Date of Join"].dt.year

# %%
df["Joining Year"].value_counts()
# Out:
# Joining Year
# 2020    29
# 2019    29
# 2021    27
# 2022    23
# 2018    23
# 2023    20
# 2017    10
# Name: count, dtype: int64

# %%
x = df["Joining Year"].value_counts().index

# %%
y = df["Joining Year"].value_counts().values

# %%
plt.plot(x , y, marker = 'o')
plt.xlabel('Year')
plt.ylabel('Staff Count')
plt.title('Staff Growth Trend Over Time')
plt.show()

# %%
 df['Name'].str[0]
# Out:
# 0      B
# 1      D
# 2      G
# 3      W
# 4      G
#       ..
# 156    M
# 157    A
# 158    K
# 159    S
# 160    K
# Name: Name, Length: 161, dtype: object

# %%
df['First Letter'] = df['Name'].str[0]

# %%
df['First Letter'].value_counts().sort_index()
# Out:
# First Letter
# A    30
# B     8
# C     6
# D     9
# E     7
# F     1
# G     4
# H     6
# J     3
# K    22
# L     4
# M    14
# N     2
# O     4
# P     4
# R     9
# S     9
# T     6
# V     5
# W     2
# Z     6
# Name: count, dtype: int64

# %%
x=df['First Letter'].value_counts().sort_index().index

# %%
y =df['First Letter'].value_counts().sort_index().values

# %%
plt.bar(x,y)  
plt.xlabel('First Letter of Name')
plt.ylabel('Count of Employees')
plt.title('Count of Employees by Starting Letter of Their Name')
plt.show()

# %%
df["Name"].str[0]
# Out:
# 0      B
# 1      D
# 2      G
# 3      W
# 4      G
#       ..
# 156    M
# 157    A
# 158    K
# 159    S
# 160    K
# Name: Name, Length: 161, dtype: object

# %%
df["First Letter"]=df["Name"].str[0]

# %%
df["First Letter"].value_counts().sort_index().reset_index()
# Out:
#    First Letter  count
# 0             A     30
# 1             B      8
# 2             C      6
# 3             D      9
# 4             E      7
# 5             F      1
# 6             G      4
# 7             H      6
# 8             J      3
# 9             K     22
# 10            L      4
# 11            M     14
# 12            N      2
# 13            O      4
# 14            P      4
# 15            R      9
# 16            S      9
# 17            T      6
# 18            V      5
# 19            W      2
# 20            Z      6

# %%
Letter_Counts= df["First Letter"].value_counts().sort_index().reset_index()

# %%
Letter_Counts.columns = ['First Letter', 'Count']

# %%
plt.figure(figsize=(7, 5))
sns.barplot(x='First Letter', y='Count', data=Letter_Counts, palette='viridis')
plt.xlabel('First Letter of Name')
plt.ylabel('Count of Employees')
plt.title('Count of Employees by Starting Letter of Their Name')
plt.show()

# %%
top_earners = df.loc[df.groupby('Job Title')['Salary'].idxmax().head()]

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='Salary', y='Job Title', data=top_earners, palette='viridis')
plt.title('Top Earners in Each Job')
plt.xlabel('Salary')
plt.ylabel('Job Title')
plt.show()
